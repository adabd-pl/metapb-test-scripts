# %%
cd "c:\Users\adabo\Downloads\hlf-operator-scripts"
# Out:
# c:\Users\adabo\Downloads\hlf-operator-scripts
# C:\Users\adabo\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is C895-4A64
#
#  Directory of c:\Users\adabo\Downloads\hlf-operator-scripts
#
# 27.03.2025  20:07    <DIR>          .
# 27.03.2025  20:07    <DIR>          ..
# 27.03.2025  18:15    <DIR>          automated-scripts
# 20.03.2025  10:07    <DIR>          caliper-benchmarks
# 17.03.2025  21:25    <DIR>          caliper-benchmarks-bft
# 23.03.2025  21:13    <DIR>          caliper-benchmarks-bft-larger
# 27.03.2025  20:08    <DIR>          caliper-benchmarks-new
# 20.03.2025  10:22    <DIR>          config-scripts
# 15.03.2025  17:52               319 config-test.json
# 15.03.2025  17:53             2�023 deploy-caliper.yaml
# 17.03.2025  21:33             2�043 deploy-caliper-bft.yaml
# 15.03.2025  09:28    <DIR>          generated_graphs
# 20.03.2025  21:17    <DIR>          more-org-configurations
# 15.03.2025  14:57             1�094 pvc.yaml
# 20.03.2025  18:32    <DIR>          results
# ...

# %%
# !kubectl delete configmap caliper-benchmarks-raft-10  --namespace fabric

# !kubectl create configmap caliper-benchmarks-raft-10 --from-file=.\caliper-benchmarks-raft-10 --namespace fabric
# Out:
# configmap "caliper-benchmarks-raft-10" deleted
# configmap/caliper-benchmarks-raft-10 created

# %%
# !kubectl delete configmap caliper-benchmarks-bft-1  --namespace fabric


# !kubectl create configmap caliper-benchmarks-bft-1 \
  --from-file=./caliper-benchmarks-bft-1 \
  --from-file=./caliper-benchmarks-general \
  --namespace fabric
# !kubectl create configmap caliper-benchmarks-bft-10 --from-file=.\caliper-benchmarks-bft-10 --namespace fabric
# Out:
# configmap "caliper-benchmarks-bft-1" deleted
# configmap/caliper-benchmarks-bft-1 created

# %%
## RAFT
# !kubectl delete job.batch/caliper-raft-10 -n fabric

# !kubectl apply -n fabric -f .\automated-scripts\caliper-scripts\deploy-caliper-raft-10.yaml
# Out:
# job.batch "caliper-raft-10" deleted
# job.batch/caliper-raft-10 created

# %%
## BFT
# !kubectl delete job.batch/caliper-bft-1 -n fabric

# !kubectl apply -n fabric -f .\automated-scripts\caliper-scripts\deploy-caliper-bft-1.yaml
# Out:
# job.batch "caliper-bft-1" deleted
# job.batch/caliper-bft-1 created
